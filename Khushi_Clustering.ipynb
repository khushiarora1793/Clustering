# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 61.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 113.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 26.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 35.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 58.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from pycaret.clustering import *

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_failure_clinical_records = fetch_ucirepo(id=519)

# data (as pandas dataframes)
X = heart_failure_clinical_records.data.features
y = heart_failure_clinical_records.data.targets

# metadata
# print(heart_failure_clinical_records.metadata)

# variable information
print(heart_failure_clinical_records.variables)
# Out:
#                         name     role        type demographic  \
# 0                        age  Feature     Integer         Age
# 1                    anaemia  Feature      Binary        None
# 2   creatinine_phosphokinase  Feature     Integer        None
# 3                   diabetes  Feature      Binary        None
# 4          ejection_fraction  Feature     Integer        None
# 5        high_blood_pressure  Feature      Binary        None
# 6                  platelets  Feature  Continuous        None
# 7           serum_creatinine  Feature  Continuous        None
# 8               serum_sodium  Feature     Integer        None
# 9                        sex  Feature      Binary         Sex
# 10                   smoking  Feature      Binary        None
# 11                      time  Feature     Integer        None
# 12               death_event   Target      Binary        None
#
#                                           description             units  \
# ...

# %%
import pandas as pd

clustering_setup = setup(data = X, verbose = False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_05a52" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05a52_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_05a52_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_05a52_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_05a52_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_05a52_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_05a52_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05a52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05a52_row0_col0" class="data row0 col0" >0.5481</td>
#       <td id="T_05a52_row0_col1" class="data row0 col1" >390.9995</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbebf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbebf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dbebf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dbebf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dbebf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dbebf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dbebf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbebf_row0_col0" class="data row0 col0" >0.5532</td>
#       <td id="T_dbebf_row0_col1" class="data row0 col1" >499.8170</td>
# ...

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd44d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd44d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fd44d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fd44d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fd44d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fd44d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fd44d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd44d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd44d_row0_col0" class="data row0 col0" >0.5339</td>
#       <td id="T_fd44d_row0_col1" class="data row0 col1" >602.9443</td>
# ...

# %%
setup(data = X, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_117d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_117d7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_117d7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_117d7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_117d7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_117d7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_117d7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_117d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_117d7_row0_col0" class="data row0 col0" >0.1049</td>
#       <td id="T_117d7_row0_col1" class="data row0 col1" >26.9262</td>
# ...

# %%
kmeansmodel_norm3 = create_model('kmeans',num_clusters=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_51c43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51c43_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_51c43_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_51c43_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_51c43_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_51c43_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_51c43_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51c43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51c43_row0_col0" class="data row0 col0" >0.1045</td>
#       <td id="T_51c43_row0_col1" class="data row0 col1" >29.4227</td>
# ...

# %%
kmeansmodel_norm4 = create_model('kmeans',num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f467" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f467_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6f467_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6f467_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6f467_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6f467_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6f467_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f467_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f467_row0_col0" class="data row0 col0" >0.1049</td>
#       <td id="T_6f467_row0_col1" class="data row0 col1" >26.9262</td>
# ...

# %%
kmeansmodel_norm4 = create_model('kmeans',num_clusters=5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_36138" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36138_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_36138_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_36138_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_36138_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_36138_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_36138_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36138_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36138_row0_col0" class="data row0 col0" >0.0961</td>
#       <td id="T_36138_row0_col1" class="data row0 col1" >25.4229</td>
# ...

# %%
setup(data = X, transformation = True, transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e1518" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1518_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e1518_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e1518_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e1518_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e1518_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e1518_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1518_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1518_row0_col0" class="data row0 col0" >0.5710</td>
#       <td id="T_e1518_row0_col1" class="data row0 col1" >624.5236</td>
# ...

# %%
kmeansmodel_trans3 = create_model('kmeans',num_clusters=3)
print(kmeansmodel_trans3)
kmeansmodel_trans4 = create_model('kmeans',num_clusters=4)
print(kmeansmodel_trans4)
kmeansmodel_trans5 = create_model('kmeans',num_clusters=5)
print(kmeansmodel_trans5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bfd12" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfd12_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bfd12_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bfd12_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bfd12_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bfd12_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bfd12_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfd12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfd12_row0_col0" class="data row0 col0" >0.5495</td>
#       <td id="T_bfd12_row0_col1" class="data row0 col1" >482.1320</td>
# ...

# %%
setup(data = X, pca = True, pca_method = 'linear' ,verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bd15" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bd15_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5bd15_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5bd15_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5bd15_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5bd15_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5bd15_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bd15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bd15_row0_col0" class="data row0 col0" >0.5535</td>
#       <td id="T_5bd15_row0_col1" class="data row0 col1" >499.6078</td>
# ...

# %%
kmeansmodel_pca3 = create_model('kmeans',num_clusters=3)
print(kmeansmodel_pca3)
kmeansmodel_pca4 = create_model('kmeans',num_clusters=4)
print(kmeansmodel_pca4)
kmeansmodel_pca5 = create_model('kmeans',num_clusters=5)
print(kmeansmodel_pca5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dfc95" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfc95_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dfc95_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dfc95_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dfc95_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dfc95_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dfc95_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfc95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfc95_row0_col0" class="data row0 col0" >0.5413</td>
#       <td id="T_dfc95_row0_col1" class="data row0 col1" >391.0813</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_45ee6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45ee6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_45ee6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_45ee6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_45ee6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_45ee6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_45ee6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45ee6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45ee6_row0_col0" class="data row0 col0" >0.0998</td>
#       <td id="T_45ee6_row0_col1" class="data row0 col1" >28.7342</td>
# ...

# %%
kmeansmodel_tn3 = create_model('kmeans',num_clusters=3)
print(kmeansmodel_tn3)
kmeansmodel_tn4 = create_model('kmeans',num_clusters=4)
print(kmeansmodel_tn4)
kmeansmodel_tn5 = create_model('kmeans',num_clusters=5)
print(kmeansmodel_tn5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3694d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3694d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3694d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3694d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3694d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3694d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3694d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3694d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3694d_row0_col0" class="data row0 col0" >0.1034</td>
#       <td id="T_3694d_row0_col1" class="data row0 col1" >31.3168</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,pca = True, pca_method = 'linear' ,verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1741c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1741c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1741c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1741c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1741c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1741c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1741c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1741c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1741c_row0_col0" class="data row0 col0" >0.0991</td>
#       <td id="T_1741c_row0_col1" class="data row0 col1" >28.7011</td>
# ...

# %%
kmeansmodel_tnp3 = create_model('kmeans',num_clusters=3)
print(kmeansmodel_tnp3)
kmeansmodel_tnp4 = create_model('kmeans',num_clusters=4)
print(kmeansmodel_tnp4)
kmeansmodel_tnp5 = create_model('kmeans',num_clusters=5)
print(kmeansmodel_tnp5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_946d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_946d3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_946d3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_946d3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_946d3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_946d3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_946d3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_946d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_946d3_row0_col0" class="data row0 col0" >0.0998</td>
#       <td id="T_946d3_row0_col1" class="data row0 col1" >30.9751</td>
# ...

# %% [markdown]
# # HEIRARICHAL

# %%
setup(data = X, verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d824" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d824_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0d824_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0d824_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0d824_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0d824_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0d824_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d824_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d824_row0_col0" class="data row0 col0" >0.5395</td>
#       <td id="T_0d824_row0_col1" class="data row0 col1" >478.6348</td>
# ...

# %%
evaluate_model(x)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
hclustmodel_3 = create_model('hclust',num_clusters=3)
print(hclustmodel_3)
hclustmodel_4 = create_model('hclust',num_clusters=4)
print(hclustmodel_4)
hclustmodel_5 = create_model('hclust',num_clusters=5)
print(hclustmodel_5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5860" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5860_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a5860_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a5860_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a5860_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a5860_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a5860_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5860_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5860_row0_col0" class="data row0 col0" >0.5035</td>
#       <td id="T_a5860_row0_col1" class="data row0 col1" >322.0706</td>
# ...

# %%
setup(data = X, normalize = True, normalize_method = 'zscore',verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7435f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7435f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7435f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7435f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7435f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7435f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7435f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7435f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7435f_row0_col0" class="data row0 col0" >0.1051</td>
#       <td id="T_7435f_row0_col1" class="data row0 col1" >23.1853</td>
# ...

# %%
hclustmodel_norm3 = create_model('hclust',num_clusters=3)
print(hclustmodel_norm3)
hclustmodel_norm4 = create_model('hclust',num_clusters=4)
print(hclustmodel_norm4)
hclustmodel_norm5 = create_model('hclust',num_clusters=5)
print(hclustmodel_norm5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7ed7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7ed7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c7ed7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c7ed7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c7ed7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c7ed7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c7ed7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7ed7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7ed7_row0_col0" class="data row0 col0" >0.0988</td>
#       <td id="T_c7ed7_row0_col1" class="data row0 col1" >23.8497</td>
# ...

# %%
setup(data = X, transformation = True, transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a4dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a4dc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2a4dc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2a4dc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2a4dc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2a4dc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2a4dc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a4dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a4dc_row0_col0" class="data row0 col0" >0.5408</td>
#       <td id="T_2a4dc_row0_col1" class="data row0 col1" >497.6851</td>
# ...

# %%
hclustmodel_trans3 = create_model('hclust',num_clusters=3)
print(hclustmodel_trans3)
hclustmodel_trans4 = create_model('hclust',num_clusters=4)
print(hclustmodel_trans4)
hclustmodel_trans5 = create_model('hclust',num_clusters=5)
print(hclustmodel_trans5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f743c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f743c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f743c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f743c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f743c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f743c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f743c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f743c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f743c_row0_col0" class="data row0 col0" >0.5189</td>
#       <td id="T_f743c_row0_col1" class="data row0 col1" >467.7175</td>
# ...

# %%
setup(data = X, pca = True, pca_method = 'linear' ,verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_09841" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09841_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_09841_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_09841_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_09841_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_09841_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_09841_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09841_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09841_row0_col0" class="data row0 col0" >0.5395</td>
#       <td id="T_09841_row0_col1" class="data row0 col1" >478.6348</td>
# ...

# %%
hclustmodel_pca3 = create_model('hclust',num_clusters=3)
print(hclustmodel_pca3)
hclustmodel_pca4 = create_model('hclust',num_clusters=4)
print(hclustmodel_pca4)
hclustmodel_pca5 = create_model('hclust',num_clusters=5)
print(hclustmodel_pca5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1563c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1563c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1563c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1563c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1563c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1563c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1563c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1563c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1563c_row0_col0" class="data row0 col0" >0.5035</td>
#       <td id="T_1563c_row0_col1" class="data row0 col1" >322.0706</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1d5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1d5c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c1d5c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c1d5c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c1d5c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c1d5c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c1d5c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1d5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1d5c_row0_col0" class="data row0 col0" >0.0632</td>
#       <td id="T_c1d5c_row0_col1" class="data row0 col1" >21.4581</td>
# ...

# %%
hclustmodel_tn3 = create_model('hclust',num_clusters=3)
print(hclustmodel_tn3)
hclustmodel_tn4 = create_model('hclust',num_clusters=4)
print(hclustmodel_tn4)
hclustmodel_tn5 = create_model('hclust',num_clusters=5)
print(hclustmodel_tn5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_976db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_976db_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_976db_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_976db_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_976db_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_976db_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_976db_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_976db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_976db_row0_col0" class="data row0 col0" >0.0795</td>
#       <td id="T_976db_row0_col1" class="data row0 col1" >23.5111</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,pca = True, pca_method = 'linear' ,verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_13604" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13604_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_13604_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_13604_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_13604_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_13604_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_13604_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13604_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13604_row0_col0" class="data row0 col0" >0.0632</td>
#       <td id="T_13604_row0_col1" class="data row0 col1" >21.4581</td>
# ...

# %%
hclustmodel_tnp3 = create_model('hclust',num_clusters=3)
print(hclustmodel_tnp3)
hclustmodel_tnp4 = create_model('hclust',num_clusters=4)
print(hclustmodel_tnp4)
hclustmodel_tnp5 = create_model('hclust',num_clusters=5)
print(hclustmodel_tnp5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_86086" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86086_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_86086_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_86086_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_86086_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_86086_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_86086_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86086_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86086_row0_col0" class="data row0 col0" >0.0795</td>
#       <td id="T_86086_row0_col1" class="data row0 col1" >23.5111</td>
# ...

# %% [markdown]
# # A P

# %%
setup(data = X, verbose=False)
x = create_model('ap')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a018" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a018_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8a018_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8a018_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8a018_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8a018_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8a018_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a018_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a018_row0_col0" class="data row0 col0" >0.2479</td>
#       <td id="T_8a018_row0_col1" class="data row0 col1" >220.5103</td>
# ...

# %%
evaluate_model(x)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
apmodel_3 = create_model('ap',num_clusters=3)
print(apmodel_3)
apmodel_4 = create_model('ap',num_clusters=4)
print(apmodel_4)
apmodel_5 = create_model('ap',num_clusters=5)
print(apmodel_5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d62ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d62ed_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d62ed_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d62ed_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d62ed_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d62ed_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d62ed_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d62ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d62ed_row0_col0" class="data row0 col0" >0.2479</td>
#       <td id="T_d62ed_row0_col1" class="data row0 col1" >220.5103</td>
# ...

# %%
setup(data = X, normalize = True, normalize_method = 'zscore',verbose=False)
x = create_model('ap')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cd378" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd378_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cd378_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cd378_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cd378_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cd378_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cd378_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd378_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd378_row0_col0" class="data row0 col0" >0.1225</td>
#       <td id="T_cd378_row0_col1" class="data row0 col1" >13.0827</td>
# ...

# %%
apmodel_3 = create_model('ap',num_clusters=3)
print(apmodel_3)
apmodel_4 = create_model('ap',num_clusters=4)
print(apmodel_4)
apmodel_5 = create_model('ap',num_clusters=5)
print(apmodel_5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_69720" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69720_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_69720_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_69720_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_69720_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_69720_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_69720_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69720_row0_col0" class="data row0 col0" >0.1225</td>
#       <td id="T_69720_row0_col1" class="data row0 col1" >13.0827</td>
# ...

# %%
setup(data = X, transformation = True, transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('ap')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac8f2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac8f2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ac8f2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ac8f2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ac8f2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ac8f2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ac8f2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac8f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac8f2_row0_col0" class="data row0 col0" >0.3031</td>
#       <td id="T_ac8f2_row0_col1" class="data row0 col1" >703.7149</td>
# ...

# %%
apmodel_t3 = create_model('ap',num_clusters=3)
print(apmodel_t3)
apmodel_t4 = create_model('ap',num_clusters=4)
print(apmodel_t4)
apmodel_t5 = create_model('ap',num_clusters=5)
print(apmodel_t5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bdf52" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdf52_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bdf52_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bdf52_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bdf52_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bdf52_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bdf52_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdf52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdf52_row0_col0" class="data row0 col0" >0.3031</td>
#       <td id="T_bdf52_row0_col1" class="data row0 col1" >703.7149</td>
# ...

# %%
setup(data = X, pca = True ,pca_method = 'linear' ,verbose=False)
x = create_model('ap')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a29d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a29d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5a29d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5a29d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5a29d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5a29d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5a29d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a29d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a29d_row0_col0" class="data row0 col0" >0.2663</td>
#       <td id="T_5a29d_row0_col1" class="data row0 col1" >229.8326</td>
# ...

# %%
apmodel_p3 = create_model('ap',num_clusters=3)
print(apmodel_p3)
apmodel_p4 = create_model('ap',num_clusters=4)
print(apmodel_p4)
apmodel_p5 = create_model('ap',num_clusters=5)
print(apmodel_p5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_19d3f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19d3f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_19d3f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_19d3f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_19d3f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_19d3f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_19d3f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19d3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19d3f_row0_col0" class="data row0 col0" >0.2663</td>
#       <td id="T_19d3f_row0_col1" class="data row0 col1" >229.8326</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('ap')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2124" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2124_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c2124_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c2124_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c2124_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c2124_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c2124_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2124_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2124_row0_col0" class="data row0 col0" >0.1032</td>
#       <td id="T_c2124_row0_col1" class="data row0 col1" >10.4685</td>
# ...

# %%
apmodel_tn3 = create_model('ap',num_clusters=3)
print(apmodel_tn3)
apmodel_tn4 = create_model('ap',num_clusters=4)
print(apmodel_tn4)
apmodel_tn5 = create_model('ap',num_clusters=5)
print(apmodel_tn5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_45c6b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45c6b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_45c6b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_45c6b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_45c6b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_45c6b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_45c6b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45c6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45c6b_row0_col0" class="data row0 col0" >0.1032</td>
#       <td id="T_45c6b_row0_col1" class="data row0 col1" >10.4685</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,pca = True ,pca_method = 'linear',verbose=False)
x = create_model('ap')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee8c4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee8c4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ee8c4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ee8c4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ee8c4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ee8c4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ee8c4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee8c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee8c4_row0_col0" class="data row0 col0" >0.1032</td>
#       <td id="T_ee8c4_row0_col1" class="data row0 col1" >10.4685</td>
# ...

# %%
apmodel_tnp3 = create_model('ap',num_clusters=3)
print(apmodel_tnp3)
apmodel_tnp4 = create_model('ap',num_clusters=4)
print(apmodel_tnp4)
apmodel_tnp5 = create_model('ap',num_clusters=5)
print(apmodel_tnp5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c56a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c56a4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c56a4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c56a4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c56a4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c56a4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c56a4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c56a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c56a4_row0_col0" class="data row0 col0" >0.1032</td>
#       <td id="T_c56a4_row0_col1" class="data row0 col1" >10.4685</td>
# ...

# %% [markdown]
# # Spectral C

# %%
setup(data = X, verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_46c1c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46c1c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_46c1c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_46c1c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_46c1c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_46c1c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_46c1c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46c1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46c1c_row0_col0" class="data row0 col0" >-0.4459</td>
#       <td id="T_46c1c_row0_col1" class="data row0 col1" >0.0000</td>
# ...

# %%
evaluate_model(x)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
scmodel_3 = create_model('sc',num_clusters=3)
print(scmodel_3)
scmodel_4 = create_model('sc',num_clusters=4)
print(scmodel_4)
scmodel_5 = create_model('sc',num_clusters=5)
print(scmodel_5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8117f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8117f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8117f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8117f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8117f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8117f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8117f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8117f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8117f_row0_col0" class="data row0 col0" >-0.4459</td>
#       <td id="T_8117f_row0_col1" class="data row0 col1" >0.0000</td>
# ...

# %%
setup(data = X, normalize = True, normalize_method = 'zscore',verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b18c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b18c1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b18c1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b18c1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b18c1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b18c1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b18c1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b18c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b18c1_row0_col0" class="data row0 col0" >0.0990</td>
#       <td id="T_b18c1_row0_col1" class="data row0 col1" >24.0728</td>
# ...

# %%
scmodel_n3 = create_model('sc',num_clusters=3)
print(scmodel_n3)
scmodel_n4 = create_model('sc',num_clusters=4)
print(scmodel_n4)
scmodel_n5 = create_model('sc',num_clusters=5)
print(scmodel_n5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_70795" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70795_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_70795_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_70795_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_70795_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_70795_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_70795_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70795_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70795_row0_col0" class="data row0 col0" >0.1014</td>
#       <td id="T_70795_row0_col1" class="data row0 col1" >25.5215</td>
# ...

# %%
setup(data = X, transformation = True, transformation_method = 'yeo-johnson' ,verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_98990" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98990_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_98990_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_98990_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_98990_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_98990_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_98990_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98990_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98990_row0_col0" class="data row0 col0" >-0.0375</td>
#       <td id="T_98990_row0_col1" class="data row0 col1" >10.3594</td>
# ...

# %%
scmodel_t3 = create_model('sc',num_clusters=3)
print(scmodel_t3)
scmodel_t4 = create_model('sc',num_clusters=4)
print(scmodel_t4)
scmodel_t5 = create_model('sc',num_clusters=5)
print(scmodel_t5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_22ddf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22ddf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_22ddf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_22ddf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_22ddf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_22ddf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_22ddf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22ddf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22ddf_row0_col0" class="data row0 col0" >0.2135</td>
#       <td id="T_22ddf_row0_col1" class="data row0 col1" >33.2351</td>
# ...

# %%
setup(data = X, pca = True ,pca_method = 'linear' ,verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d11a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d11a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9d11a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9d11a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9d11a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9d11a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9d11a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d11a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d11a_row0_col0" class="data row0 col0" >-0.4459</td>
#       <td id="T_9d11a_row0_col1" class="data row0 col1" >0.0000</td>
# ...

# %%
scmodel_p3 = create_model('sc',num_clusters=3)
print(scmodel_p3)
scmodel_p4 = create_model('sc',num_clusters=4)
print(scmodel_p4)
scmodel_p5 = create_model('sc',num_clusters=5)
print(scmodel_p5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1be0d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1be0d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1be0d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1be0d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1be0d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1be0d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1be0d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1be0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1be0d_row0_col0" class="data row0 col0" >-0.4459</td>
#       <td id="T_1be0d_row0_col1" class="data row0 col1" >0.0000</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson',verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e78ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e78ef_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e78ef_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e78ef_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e78ef_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e78ef_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e78ef_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e78ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e78ef_row0_col0" class="data row0 col0" >0.0269</td>
#       <td id="T_e78ef_row0_col1" class="data row0 col1" >14.9248</td>
# ...

# %%
scmodel_tn3 = create_model('sc',num_clusters=3)
print(scmodel_tn3)
scmodel_tn4 = create_model('sc',num_clusters=4)
print(scmodel_tn4)
scmodel_tn5 = create_model('sc',num_clusters=5)
print(scmodel_tn5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a1fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a1fe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2a1fe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2a1fe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2a1fe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2a1fe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2a1fe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a1fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a1fe_row0_col0" class="data row0 col0" >0.0748</td>
#       <td id="T_2a1fe_row0_col1" class="data row0 col1" >18.9218</td>
# ...

# %%
setup(data = X, transformation = True, normalize = True, normalize_method = 'zscore',transformation_method = 'yeo-johnson' ,pca = True ,pca_method = 'linear',verbose=False)
x = create_model('sc')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c3420" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3420_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c3420_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c3420_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c3420_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c3420_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c3420_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3420_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3420_row0_col0" class="data row0 col0" >0.0085</td>
#       <td id="T_c3420_row0_col1" class="data row0 col1" >13.2809</td>
# ...

# %%
scmodel_tnp3 = create_model('sc',num_clusters=3)
print(scmodel_tnp3)
scmodel_tnp4 = create_model('sc',num_clusters=4)
print(scmodel_tnp4)
scmodel_tnp5 = create_model('sc',num_clusters=5)
print(scmodel_tnp5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4dfe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4dfe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d4dfe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d4dfe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d4dfe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d4dfe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d4dfe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4dfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4dfe_row0_col0" class="data row0 col0" >0.0748</td>
#       <td id="T_d4dfe_row0_col1" class="data row0 col1" >18.9218</td>
# ...
